# %%
import os
from IPython.display import Image


if os.getcwd().endswith("code"):
    os.chdir("..")

# %%
! pwd
# Out:
# /mnt/w/game_cibog_2022

# %% [markdown]
# # Downloading cellranger
#
# Cellranger is available from 10X Genomics and only suitable for their kits/libraries.
#
# Visit the cellranger website (https://support.10xgenomics.com/single-cell-gene-expression/software/downloads/latest, might require registration) and download cellranger (linux) and loupe browsers (choose your OS, e.g. Windows):

# %%
! cd tools && wget -O cellranger-6.1.2.tar.gz "https://cf.10xgenomics.com/releases/cell-exp/cellranger-6.1.2.tar.gz?Expires=1641958065&Policy=eyJTdGF0ZW1lbnQiOlt7IlJlc291cmNlIjoiaHR0cHM6Ly9jZi4xMHhnZW5vbWljcy5jb20vcmVsZWFzZXMvY2VsbC1leHAvY2VsbHJhbmdlci02LjEuMi50YXIuZ3oiLCJDb25kaXRpb24iOnsiRGF0ZUxlc3NUaGFuIjp7IkFXUzpFcG9jaFRpbWUiOjE2NDE5NTgwNjV9fX1dfQ__&Signature=g2re3W~2ybB0B3sFtdXmM~W2fWTUF4AMKF~46oEqQ0lV9W4IBfJ-7kpnSgAHj7KbIsB-Pu7l2l3gX8i8evLnnmru3x8i6sp72K5eRYgpY7JxypcTuWi9sbF1p8ezHoL5C9dsR0QI3Gx9ZDbu2VA5wrGV7wRi0ehnbXTsUAjOnG87lKAq7khwC~HvcOux9Og8B0WzbSb2Hb1klEoAj5n5Xd~-ta8EoqjeqVdgue0-DVXD36kvU5OkYWOTehNZtTkXxBdDwgbjbKw-8XgZYnie1p8lfDWTZRU16o81-lovv0yq3XFkvh89Kuj84GjwxU6s-~d9Xq-BE8g28DG8vLlGxg__&Key-Pair-Id=APKAI7S6A5RYOXBWRPDA"

# %% [markdown]
# also download the human reference file (which will also be extracted right away):

# %%
! cd references && wget https://cf.10xgenomics.com/supp/cell-exp/refdata-gex-GRCh38-2020-A.tar.gz && tar xfz refdata-gex-GRCh38-2020-A.tar.gz

# %% [markdown]
# Extract the software

# %%
! cd tools && tar xfz cellranger-6.1.2.tar.gz

# %% [markdown]
# Now you should briefly verify whether the software was correctly installed and works as intended:

# %%
! ./tools/cellranger-6.1.2/bin/cellranger sitecheck
# Out:
# cellranger sitecheck (cellranger-6.1.2)
# Copyright (c) 2021 10x Genomics, Inc.  All rights reserved.
# -------------------------------------------------------------------------------
# Fri Jan 21 16:22:30 CET 2022
#
# =====================================================================
# System Info
# uname -a
# ---------------------------------------------------------------------
# Linux spectre3 4.19.104-microsoft-standard #1 SMP Wed Feb 19 06:37:35 UTC 2020 x86_64 x86_64 x86_64 GNU/Linux
# =====================================================================
#
# =====================================================================
# Linux Distro
# cat /etc/*-release | sort -u
# ---------------------------------------------------------------------
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# DISTRIB_CODENAME=focal
# DISTRIB_DESCRIPTION="Ubuntu 20.04.2 LTS"
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=20.04
# HOME_URL="https://www.ubuntu.com/"
# ID=ubuntu
# ID_LIKE=debian
# NAME="Ubuntu"
# PRETTY_NAME="Ubuntu 20.04.2 LTS"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# SUPPORT_URL="https://help.ubuntu.com/"
# UBUNTU_CODENAME=focal
# VERSION="20.04.2 LTS (Focal Fossa)"
# VERSION_CODENAME=focal
# VERSION_ID="20.04"
# =====================================================================
#
# =====================================================================
# Kernel Build
# cat /proc/version
# ---------------------------------------------------------------------
# Linux version 4.19.104-microsoft-standard (oe-user@oe-host) (gcc version 8.2.0 (GCC)) #1 SMP Wed Feb 19 06:37:35 UTC 2020
# =====================================================================
#
# =====================================================================
# glibc version
# ldd --version | head -n 1
# ---------------------------------------------------------------------
# ldd (Ubuntu GLIBC 2.31-0ubuntu9.2) 2.31
# =====================================================================
#
# =====================================================================
# CPU Model
# grep -m 1 'model name' /proc/cpuinfo | cut -d ':' -f 2 | sed 's/^[ \t]*//'
# ---------------------------------------------------------------------
# AMD Ryzen 7 3700X 8-Core Processor
# =====================================================================
#
# =====================================================================
# CPU Sockets
# grep 'physical id' /proc/cpuinfo | sort -u | wc -l
# ---------------------------------------------------------------------
# 1
# =====================================================================
#
# =====================================================================
# CPU Cores
# grep -c processor /proc/cpuinfo
# ---------------------------------------------------------------------
# 16
# =====================================================================
#
# =====================================================================
# CPU Support
# grep -m 1 'flags' /proc/cpuinfo | cut -d ':' -f 2 | sed 's/^\s*//'
# ---------------------------------------------------------------------
# fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm rep_good nopl cpuid extd_apicid pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibpb stibp vmmcall fsgsbase bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 xsaves clzero xsaveerptr virt_ssbd arat umip rdpid
# =====================================================================
#
# =====================================================================
# Memory Total
# grep MemTotal /proc/meminfo | cut -d ':' -f 2 | sed 's/^[ \t]*//'
# ---------------------------------------------------------------------
# 52582416 kB
# =====================================================================
#
# =====================================================================
# Disk Space
# df -Ph | awk '{print $2, $3, $4}'
# ---------------------------------------------------------------------
# Size Used Avail
# 251G 95G 144G
# 26G 365M 25G
# 251G 7.0G 232G
# 26G 12K 26G
# 251G 123M 239G
# 370M 370M 0
# 238G 190G 49G
# 26G 0 26G
# 26G 8.0K 26G
# 26G 0 26G
# 26G 0 26G
# 26G 0 26G
# 26G 0 26G
# 238G 190G 49G
# 238G 190G 49G
# 238G 190G 49G
# 932G 853G 80G
# 1.9T 980G 884G
# 932G 849G 83G
# 1.9T 1.1T 758G
# 1.9T 67G 1.8T
# =====================================================================
#
# =====================================================================
# Filesystem Options
# mount | cut -d ' ' -f 5,6
# ---------------------------------------------------------------------
# ext4 (rw,relatime,discard,errors=remount-ro,data=ordered)
# tmpfs (rw,relatime)
# ext4 (rw,relatime,discard,errors=remount-ro,data=ordered)
# tmpfs (rw,nosuid,noexec,noatime,mode=755)
# tmpfs (rw,nosuid,noexec,noatime,mode=755)
# ext4 (rw,relatime,discard,errors=remount-ro,data=ordered)
# iso9660 (ro,relatime,nojoliet,check=s,map=n,blocksize=2048)
# 9p (ro,relatime,dirsync,aname=tools;fmask=022,loose,access=client,trans=fd,rfd=6,wfd=6)
# devtmpfs (rw,nosuid,relatime,size=26288800k,nr_inodes=6572200,mode=755)
# sysfs (rw,nosuid,nodev,noexec,noatime)
# proc (rw,nosuid,nodev,noexec,noatime)
# devpts (rw,nosuid,noexec,noatime,gid=5,mode=620,ptmxmode=000)
# tmpfs (rw,nosuid,noexec,noatime,mode=755)
# tmpfs (rw,nosuid,nodev,noexec,noatime)
# tmpfs (rw,nosuid,nodev,noatime)
# tmpfs (rw,nosuid,nodev,noexec,noatime,mode=755)
# binfmt_misc (rw,relatime)
# tmpfs (rw,nosuid,nodev,noexec,relatime,mode=755)
# 9p (ro,nosuid,nodev,noatime,dirsync,aname=drivers;fmask=222;dmask=222,mmap,access=client,msize=65536,trans=fd,rfd=4,wfd=4)
# 9p (ro,nosuid,nodev,noatime,dirsync,aname=lib;fmask=222;dmask=222,mmap,access=client,msize=65536,trans=fd,rfd=4,wfd=4)
# cgroup2 (rw,nosuid,nodev,noexec,relatime)
# cgroup (rw,nosuid,nodev,noexec,relatime,cpuset)
# cgroup (rw,nosuid,nodev,noexec,relatime,cpu)
# cgroup (rw,nosuid,nodev,noexec,relatime,cpuacct)
# cgroup (rw,nosuid,nodev,noexec,relatime,blkio)
# cgroup (rw,nosuid,nodev,noexec,relatime,memory)
# cgroup (rw,nosuid,nodev,noexec,relatime,devices)
# cgroup (rw,nosuid,nodev,noexec,relatime,freezer)
# cgroup (rw,nosuid,nodev,noexec,relatime,net_cls)
# cgroup (rw,nosuid,nodev,noexec,relatime,perf_event)
# cgroup (rw,nosuid,nodev,noexec,relatime,net_prio)
# cgroup (rw,nosuid,nodev,noexec,relatime,hugetlb)
# cgroup (rw,nosuid,nodev,noexec,relatime,pids)
# cgroup (rw,nosuid,nodev,noexec,relatime,rdma)
# 9p (rw,noatime,dirsync,aname=drvfs;path=C:\;uid=1000;gid=1000;metadata;umask=22;fmask=11;symlinkroot=/mnt/,mmap,access=client,msize=65536,trans=fd,rfd=8,wfd=8)
# 9p (rw,noatime,dirsync,aname=drvfs;path=F:\;uid=1000;gid=1000;metadata;umask=22;fmask=11;symlinkroot=/mnt/,mmap,access=client,msize=65536,trans=fd,rfd=8,wfd=8)
# 9p (rw,noatime,dirsync,aname=drvfs;path=G:\;uid=1000;gid=1000;metadata;umask=22;fmask=11;symlinkroot=/mnt/,mmap,access=client,msize=65536,trans=fd,rfd=8,wfd=8)
# 9p (rw,noatime,dirsync,aname=drvfs;path=S:\;uid=1000;gid=1000;metadata;umask=22;fmask=11;symlinkroot=/mnt/,mmap,access=client,msize=65536,trans=fd,rfd=8,wfd=8)
# 9p (rw,noatime,dirsync,aname=drvfs;path=T:\;uid=1000;gid=1000;metadata;umask=22;fmask=11;symlinkroot=/mnt/,mmap,access=client,msize=65536,trans=fd,rfd=8,wfd=8)
# 9p (rw,noatime,dirsync,aname=drvfs;path=W:\;uid=1000;gid=1000;metadata;umask=22;fmask=11;symlinkroot=/mnt/,mmap,access=client,msize=65536,trans=fd,rfd=8,wfd=8)
# 9p (rw,noatime,dirsync,aname=drvfs;path=T:\;uid=1000;gid=1000;metadata;umask=22;fmask=11;symlinkroot=/mnt/,mmap,access=client,msize=65536,trans=fd,rfd=8,wfd=8)
# 9p (rw,noatime,dirsync,aname=drvfs;path=T:\;uid=1000;gid=1000;metadata;umask=22;fmask=11;symlinkroot=/mnt/,mmap,access=client,msize=65536,trans=fd,rfd=8,wfd=8)
# tmpfs (rw,relatime)
# overlay (rw,relatime,lowerdir=/containers/services/docker/lower,upperdir=/containers/services/docker/tmp/upper,workdir=/containers/services/docker/tmp/work)
# =====================================================================
#
# =====================================================================
# User Limits
# bash -c 'ulimit -a'
# ---------------------------------------------------------------------
# core file size          (blocks, -c) 0
# data seg size           (kbytes, -d) unlimited
# scheduling priority             (-e) 0
# file size               (blocks, -f) unlimited
# pending signals                 (-i) 205381
# max locked memory       (kbytes, -l) 64
# max memory size         (kbytes, -m) unlimited
# open files                      (-n) 4096
# pipe size            (512 bytes, -p) 8
# POSIX message queues     (bytes, -q) 819200
# real-time priority              (-r) 0
# stack size              (kbytes, -s) 8192
# cpu time               (seconds, -t) unlimited
# max user processes              (-u) 205381
# virtual memory          (kbytes, -v) unlimited
# file locks                      (-x) unlimited
# =====================================================================
#
# =====================================================================
# User Limits (hard)
# bash -c 'ulimit -aH'
# ---------------------------------------------------------------------
# core file size          (blocks, -c) unlimited
# data seg size           (kbytes, -d) unlimited
# scheduling priority             (-e) 0
# file size               (blocks, -f) unlimited
# pending signals                 (-i) 205381
# max locked memory       (kbytes, -l) 64
# max memory size         (kbytes, -m) unlimited
# open files                      (-n) 4096
# pipe size            (512 bytes, -p) 8
# POSIX message queues     (bytes, -q) 819200
# real-time priority              (-r) 0
# stack size              (kbytes, -s) unlimited
# cpu time               (seconds, -t) unlimited
# max user processes              (-u) 205381
# virtual memory          (kbytes, -v) unlimited
# file locks                      (-x) unlimited
# =====================================================================
#
# =====================================================================
# Global File Limit
# cat /proc/sys/fs/file-{max,nr}
# ---------------------------------------------------------------------
# 5256618
# 3360	0	5256618
# =====================================================================
#
# =====================================================================
# Memory config
# sysctl vm
# ---------------------------------------------------------------------
# vm.admin_reserve_kbytes = 8192
# vm.block_dump = 0
# vm.compact_unevictable_allowed = 1
# vm.dirty_background_bytes = 0
# vm.dirty_background_ratio = 10
# vm.dirty_bytes = 0
# vm.dirty_expire_centisecs = 3000
# vm.dirty_ratio = 20
# vm.dirty_writeback_centisecs = 500
# vm.dirtytime_expire_seconds = 43200
# vm.extfrag_threshold = 500
# vm.hugetlb_shm_group = 0
# vm.laptop_mode = 0
# vm.legacy_va_layout = 0
# vm.lowmem_reserve_ratio = 256	256	32	0
# vm.max_map_count = 65530
# vm.min_free_kbytes = 67584
# vm.mmap_min_addr = 65536
# vm.nr_hugepages = 0
# vm.nr_overcommit_hugepages = 0
# vm.oom_dump_tasks = 1
# vm.oom_kill_allocating_task = 0
# vm.overcommit_kbytes = 0
# vm.overcommit_memory = 0
# vm.overcommit_ratio = 50
# vm.page-cluster = 3
# vm.panic_on_oom = 0
# vm.percpu_pagelist_fraction = 0
# vm.stat_interval = 1
# vm.swappiness = 60
# vm.user_reserve_kbytes = 131072
# vm.vfs_cache_pressure = 100
# vm.watermark_scale_factor = 10
# =====================================================================
#
# =====================================================================
# THP memory config
# cat /sys/kernel/mm/*transparent_hugepage/enabled
# ---------------------------------------------------------------------
# [always] madvise never
# =====================================================================
#
# =====================================================================
# cgroups
# cat /proc/self/cgroup
# ---------------------------------------------------------------------
# 14:name=systemd:/
# 13:rdma:/
# 12:pids:/
# 11:hugetlb:/
# 10:net_prio:/
# 9:perf_event:/
# 8:net_cls:/
# 7:freezer:/
# 6:devices:/
# 5:memory:/
# 4:blkio:/
# 3:cpuacct:/
# 2:cpu:/
# 1:cpuset:/
# 0::/
# =====================================================================
#
# =====================================================================
# cgroup mem stats
# cat /sys/fs/cgroup/memory//memory.stat
# ---------------------------------------------------------------------
# cache 1326170112
# rss 5407973376
# rss_huge 2738880512
# shmem 381984768
# mapped_file 298586112
# dirty 0
# writeback 0
# swap 0
# pgpgin 19804653
# pgpgout 18827827
# pgfault 19986252
# pgmajfault 3168
# inactive_anon 357179392
# active_anon 5433262080
# inactive_file 598745088
# active_file 345624576
# unevictable 0
# hierarchical_memory_limit 9223372036854771712
# hierarchical_memsw_limit 9223372036854771712
# total_cache 1440653312
# total_rss 5556834304
# total_rss_huge 2841640960
# total_shmem 382390272
# total_mapped_file 350085120
# total_dirty 0
# total_writeback 0
# total_swap 0
# total_pgpgin 19863030
# total_pgpgout 18845891
# total_pgfault 20040339
# total_pgmajfault 3399
# total_inactive_anon 357625856
# total_active_anon 5585297408
# total_inactive_file 701067264
# total_active_file 362856448
# total_unevictable 0
# =====================================================================
#
# =====================================================================
# memory soft limit
# cat /sys/fs/cgroup/memory//memory.*soft_limit_in_bytes
# ---------------------------------------------------------------------
# 9223372036854771712
# =====================================================================
#
# =====================================================================
# memory hard limit
# cat /sys/fs/cgroup/memory//memory.limit_in_bytes
# ---------------------------------------------------------------------
# 9223372036854771712
# =====================================================================
#
# =====================================================================
# memory swap limit
# cat /sys/fs/cgroup/memory//memory.memsw.limit_in_bytes
# ---------------------------------------------------------------------
# 9223372036854771712
# =====================================================================
#
# =====================================================================
# Container
# [ -e /.dockerenv ] || [ -e /.dockerinit ] || [ ! -z "$container" ] || grep -m 1 -E 'docker|lxc' /proc/1/cgroup > /dev/null && echo 'Detected'
# ---------------------------------------------------------------------
# =====================================================================
#
# =====================================================================
# init process
# head -n 1 /proc/1/sched | cut -d ' ' -f 1
# ---------------------------------------------------------------------
# init
# =====================================================================
#
# =====================================================================
# SGE Submit
# which qsub
# ---------------------------------------------------------------------
# =====================================================================
#
# =====================================================================
# LSF Submit
# which bsub
# ---------------------------------------------------------------------
# =====================================================================
#
# =====================================================================
# BCL2FASTQ 1
# which configureBclToFastq.pl
# ---------------------------------------------------------------------
# =====================================================================
#
# =====================================================================
# BCL2FASTQ 2
# which bcl2fastq
# ---------------------------------------------------------------------
# =====================================================================
#
# =====================================================================
# Java
# which java
# ---------------------------------------------------------------------
# /usr/bin/java
# =====================================================================
#
# =====================================================================
# Java Version
# java -version 2>&1 | cat
# ---------------------------------------------------------------------
# openjdk version "14.0.2" 2020-07-14
# OpenJDK Runtime Environment (build 14.0.2+12-Ubuntu-120.04)
# OpenJDK 64-Bit Server VM (build 14.0.2+12-Ubuntu-120.04, mixed mode, sharing)
# =====================================================================
#
# =====================================================================
# 10X Refdata
# echo $TENX_REFDATA
# ---------------------------------------------------------------------
#
# =====================================================================
#
# =====================================================================
# 10X Refdata Version
# cat $TENX_REFDATA/version
# ---------------------------------------------------------------------
# =====================================================================
#
# =====================================================================
# qconf
# which qconf
# ---------------------------------------------------------------------
# =====================================================================
#
# =====================================================================
# slurm info
# sinfo -O nodes,maxcpuspernode,memory,time
# ---------------------------------------------------------------------
# =====================================================================
#
# =====================================================================
# MRP
# mrp --version
# ---------------------------------------------------------------------
# v4.0.6
# =====================================================================
#
# =====================================================================
# mrp templates
# ls $(dirname $(dirname $(which mrp)))/jobmanagers/*.template
# ---------------------------------------------------------------------
# =====================================================================

# %% [markdown]
# # Downloading the data

# %%
! mkdir reads
! mkdir reads/SUM159DMSO
! mkdir reads/SUM159RDMSO

# %%
! cd reads/SUM159DMSO/ && fastq-dump --split-files --gzip SRR9050597
! cd reads/SUM159DMSO/ && fastq-dump --split-files --gzip SRR9050598
! cd reads/SUM159DMSO/ && fastq-dump --split-files --gzip SRR9050599
! cd reads/SUM159DMSO/ && fastq-dump --split-files --gzip SRR9050600

# %%
! cd reads/SUM159RDMSO/ && fastq-dump --split-files --gzip SRR9050605
! cd reads/SUM159RDMSO/ && fastq-dump --split-files --gzip SRR9050606
! cd reads/SUM159RDMSO/ && fastq-dump --split-files --gzip SRR9050607
! cd reads/SUM159RDMSO/ && fastq-dump --split-files --gzip SRR9050608

# %% [markdown]
# Unfortunately the SRA-format is incompatible with cellranger. You need to manually process it according to https://kb.10xgenomics.com/hc/en-us/articles/115003802691-How-do-I-prepare-Sequence-Read-Archive-SRA-data-from-NCBI-for-Cell-Ranger- .
#
# Based on the read length and the attributes listed in the meta data, we know that:
#
#     SRR9291388_1.fastq is Read 1
#     SRR9291388_2.fastq is Read 2
#     SRR9291388_3.fastq is Index 1
#
# Cell Ranger requires FASTQ file names to follow the bcl2fastq file naming convention.
#
# [Sample Name]_S1_L00[Lane Number]_[Read Type]_001.fastq.gz
#
# Where Read Type is one of:
#
#     I1: Sample index read (optional)
#     I2: Sample index read (optional)
#     R1: Read 1 (required)
#     R2: Read 2 (required)

# %%
! mv sc/SUM159DMSO/SRR9050597_1.fastq.gz sc/SUM159DMSO/SRR9050597_S1_L001_R1_001.fastq.gz
! mv sc/SUM159DMSO/SRR9050597_2.fastq.gz sc/SUM159DMSO/SRR9050597_S1_L001_R2_001.fastq.gz

! mv sc/SUM159DMSO/SRR9050598_1.fastq.gz sc/SUM159DMSO/SRR9050598_S1_L001_R1_001.fastq.gz
! mv sc/SUM159DMSO/SRR9050598_2.fastq.gz sc/SUM159DMSO/SRR9050598_S1_L001_R2_001.fastq.gz

! mv sc/SUM159DMSO/SRR9050599_1.fastq.gz sc/SUM159DMSO/SRR9050599_S1_L001_R1_001.fastq.gz
! mv sc/SUM159DMSO/SRR9050599_2.fastq.gz sc/SUM159DMSO/SRR9050599_S1_L001_R2_001.fastq.gz

! mv sc/SUM159DMSO/SRR9050600_1.fastq.gz sc/SUM159DMSO/SRR9050600_S1_L001_R1_001.fastq.gz
! mv sc/SUM159DMSO/SRR9050600_2.fastq.gz sc/SUM159DMSO/SRR9050600_S1_L001_R2_001.fastq.gz

# %%
! mv sc/SUM159RDMSO/SRR9050605_1.fastq.gz sc/SUM159RDMSO/SRR9050605_S1_L001_R1_001.fastq.gz
! mv sc/SUM159RDMSO/SRR9050605_2.fastq.gz sc/SUM159RDMSO/SRR9050605_S1_L001_R2_001.fastq.gz

! mv sc/SUM159RDMSO/SRR9050606_1.fastq.gz sc/SUM159RDMSO/SRR9050606_S1_L001_R1_001.fastq.gz
! mv sc/SUM159RDMSO/SRR9050606_2.fastq.gz sc/SUM159RDMSO/SRR9050606_S1_L001_R2_001.fastq.gz

! mv sc/SUM159RDMSO/SRR9050607_1.fastq.gz sc/SUM159RDMSO/SRR9050607_S1_L001_R1_001.fastq.gz
! mv sc/SUM159RDMSO/SRR9050607_2.fastq.gz sc/SUM159RDMSO/SRR9050607_S1_L001_R2_001.fastq.gz

! mv sc/SUM159RDMSO/SRR9050608_1.fastq.gz sc/SUM159RDMSO/SRR9050608_S1_L001_R1_001.fastq.gz
! mv sc/SUM159RDMSO/SRR9050608_2.fastq.gz sc/SUM159RDMSO/SRR9050608_S1_L001_R2_001.fastq.gz

# %% [markdown]
# Consult the presentation for structuring the sc folder and the calls file. When properly set up, it should look like this: (the folders in the calls subfolder in sc will only appear after having run cellranger!)
#
# <img src="../images/folder_layout.png" />

# %% [markdown]
# # Running cellranger

# %%
! bash sc/calls/calls.sh

# %% [markdown]
# After having executed cellranger, we must merge both datasets:

# %%
! cd sc/aggr_calls/ && ../../tools/cellranger-6.1.2/bin/cellranger aggr --localmem 30 --localcores 8 --csv aggr_samples.csv --id SUM159DMSO_RDMSO
